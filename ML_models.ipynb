# %% [markdown]
# <a href="https://colab.research.google.com/github/Avya-9/Avya-9/blob/main/ML_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret

# %%
from pycaret.regression import setup, compare_models, evaluate_model, predict_model
import pandas as pd
from sklearn.datasets import fetch_california_housing

df="/content/Data_Prediction.xlsx"
data=pd.read_excel(df)
x=data.drop('Target',axis=1)
y=data['Target']

reg = setup(data=data, target='Target', verbose=False)

best_model = compare_models()

evaluate_model(best_model)

predictions = predict_model(best_model, data=data)

print(predictions.head())
# Out:
# <style type="text/css">
# #T_94643 th {
#   text-align: left;
# }
# ...
